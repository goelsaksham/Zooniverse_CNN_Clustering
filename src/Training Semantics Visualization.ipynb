# %% [markdown]
# ## Regime 1
#
# Input Shape: (224, 224, 3)
#
# DEC Model: 2048, 500, 500, 2000, 10
#
# Generator:

# %%
import cv2
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
pca_plot_img = cv2.imread(f'../data/figs/encoding_pca_features_2.png')
plt.imshow(pca_plot_img)

# %%
import pandas as pd

# %%
dec_log, ptrain_log = pd.read_csv(f'results/temp/dec_log.csv'), pd.read_csv(f'results/temp/pretrain_log.csv')
dec_log.head()
# Out:
#    iter      acc      nmi      ari     loss
# 0     0  0.67845  0.09505  0.12735  0.00000
# 1   140  0.67784  0.09492  0.12650  0.00116
# 2   280  0.67906  0.09613  0.12824  0.00310
# 3   420  0.68076  0.09768  0.13068  0.01239
# 4   560  0.68276  0.09918  0.13358  0.02313

# %%
ptrain_log.head()
# Out:
#    epoch      loss
# 0      0  0.008582
# 1      1  0.003743
# 2      2  0.002924
# 3      3  0.002506
# 4      4  0.002209

# %%
dec_log.tail()
# Out:
#       iter      acc      nmi      ari     loss
# 138  19320  0.69589  0.11506  0.15347  0.01919
# 139  19460  0.69620  0.11530  0.15396  0.02076
# 140  19600  0.69555  0.11546  0.15295  0.01832
# 141  19740  0.69559  0.11525  0.15300  0.01916
# 142  19880  0.69375  0.11372  0.15015  0.02298

# %%
ptrain_log.tail()
# Out:
#     epoch      loss
# 95     95  0.001478
# 96     96  0.001474
# 97     97  0.001463
# 98     98  0.001463
# 99     99  0.001454

# %%
plt.plot(ptrain_log['loss'])
plt.title('Reconstruction Loss')
plt.ylabel('Loss')
plt.xlabel('Epochs #')
# Out:
# Text(0.5, 0, 'Epochs #')

# %%
plt.plot(dec_log['nmi'])
plt.title('Clustering NMI')
plt.ylabel('NMI')
plt.xlabel('Interval (# of 140 iterations)')
# Out:
# Text(0.5, 0, 'Interval (# of 140 iterations)')

# %%
plt.plot(dec_log['acc'])
plt.title('Clustering ACC')
plt.ylabel('ACC')
plt.xlabel('Interval (# of 140 iterations)')
# Out:
# Text(0.5, 0, 'Interval (# of 140 iterations)')
